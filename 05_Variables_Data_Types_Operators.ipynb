# %% [markdown]
# # Data Types, Operators, and Variables<a id="top"></a>
#
#    #### - Data Types
#    #### - Relational Operators
#    #### - Assignment Operators
#    #### - Variables
#    #### - Correct / Incorrect Examples
#    ##### - References

# %% [markdown]
# <hr>

# %% [markdown]
# ## Data Types
#
# In programming we work with different types of data.  Here we are going to talk about four types of data types.

# %% [markdown]
# ![python_Data_Types_2.jpg](attachment:python_Data_Types_2.jpg)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Relational Operators

# %% [markdown]
# ![Python_Relational_Operators.jpg](attachment:Python_Relational_Operators.jpg)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# ![python_Compound_Assignment_Operators.jpg](attachment:python_Compound_Assignment_Operators.jpg)

# %% [markdown]
# ## Variables
#
#    #### Variables are a temporary storage area for data.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Rules for naming Variables<a id="rules"></a>
#
#    #### 1. Must start with a letter OR underscore
#    #### 2. Cannot start with a number
#    #### 3. Cannot contain spaces
#    #### 4. Can only contain alpha-numeric characters and underscore (A-z, 0-9, _ )
#    #### 4. Variable names are case sensitive. Dave, DAve, DAVe, and DAVE are all different variable names.
#    #### 5. Cannot be a Python reserved keyword (i.e., and, if False, True, etc..)

# %% [markdown]
# <hr>

# %% [markdown]
# #### Recommendations for naming variables in Python<a id="recommendations"></a>
#
#    #### 1. Start with a lowercase letter.
#    #### 2. Use Camel case (i.e., myNumber, intCounter)
#    #### 3. Use meaningful names based on the data they hold.  Names that are easy to remember
#    #### 4. Don't use built-in names like type, print, def, etc..

# %% [markdown]
# <hr>

# %% [markdown]
# ![Python_Variables_01.jpg](attachment:Python_Variables_01.jpg)

# %% [markdown]
# ## Correct Examples<a id="correct"></a>
#
# #### The below examples are all string variables.

# %%
#Legal variable names:
myvar = "Dave"
my_var = "Dave"
_my_var = "Dave"
myVar = "Dave"
MYVAR = "Dave"
myvar2 = "Dave"

# %% [markdown]
# #### The below examples are all number variables.

# %%
#Legal numeric variable names:

num1 = 44
num2 = 3423423.234234
num3 = -32.55
num4 = 5j

# %% [markdown]
# ## Incorrect Examples<a id="incorrect"><a/>
#
# #### These examples show exemption errors because of the variable name.  The string "Dave" is correct throughout these examples.

# %%
#Illegal variable names:

2myvar = "Dave"
# Out:
#   File "<ipython-input-3-43e8a6b13cf0>", line 3
#     2myvar = "Dave"
#          ^
# SyntaxError: invalid syntax

# %%
#Illegal variable names:

my-var = "Dave"
# Out:
#   File "<ipython-input-4-6de069e3f210>", line 3
#     my-var = "Dave"
#                    ^
# SyntaxError: can't assign to operator

# %%
#Illegal variable names:

my var = "Dave"
# Out:
#   File "<ipython-input-5-39775f7c6a16>", line 3
#     my var = "Dave"
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <hr>

# %% [markdown]
# ## Resources<a id="resources"><a/>

# %% [markdown]
# #### Sources for deeper learning:
#
#    1. <a href="https://www.w3schools.com/python/python_variables.asp">W3Schools.com</a> Python Variables
#
#
#    2. Python <a href="https://www.youtube.com/watch?v=cQT33yu9pY8">Variables:</a> - Python Tutorial for Beginners with Examples.
#
#
# #### Sources used in this document:
#
#    Python <a href="https://www.w3schools.com/python/python_booleans.asp">Booleans</a> from W3Schools.com
#
#    Python <a href="https://www.w3schools.com/python/python_variables.asp">Variables</a> from W3Schools.com
#
#    <a href="https://realpython.com/python-variables/">Variables</a> in Python, from RealPython.com
